# %% [markdown]
# <center> <h1> Object Size Experiments </h1> </center>

# %%
#import all packages needed
import json
import pandas as pd
import matplotlib.pyplot as plt

# Centralize the graphs and tables.
from IPython.core.display import HTML, display


display(HTML("""
<style>
.output {
    display: flex;
    align-items: center;
    text-align: center;
}
</style>
"""))
# Out:
# <style>
# .output {
#     display: flex;
#     align-items: center;
#     text-align: center;
# }
# </style>

# %% [markdown]
# <center> <h3> Sequential Write Bandwidth vs. Object Sizes </h3> </center>

# %%
object_sizes = ['0.25MB','0.5MB', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB', '64MB']

w_bw_list = []
for i in range(len(object_sizes)):
    with open('./data/W'+object_sizes[i]+'.json') as f:
        data = json.load(f)
    w_bw_list.append([object_sizes[i],data['jobs'][0]['write']['bw']/1000])

w_bw_df = pd.DataFrame(w_bw_list, columns=['object size','bandwidth[MB/s]'])
display(w_bw_df)

fig = w_bw_df.plot(x='object size', y='bandwidth[MB/s]', title='Write Bandwidth' ,legend=False, xticks=w_bw_df.index , figsize=[8,5])
fig.set_ylabel("bandwidth[MB/s]")
fig.set_ylim(ymin=0)
plt.show()
# Out:
#   object size  bandwidth[MB/s]
# 0      0.25MB           39.426
# 1       0.5MB           32.034
# 2         1MB           36.353
# 3         2MB           37.951
# 4         4MB           38.569
# 5         8MB           34.374
# 6        16MB           37.418
# 7        32MB           35.766
# 8        64MB           37.729

# %% [markdown]
# <center> <h3> Sequential Read Bandwidth vs. Object Sizes </h3> </center>

# %%
object_sizes = ['0.25MB','0.5MB', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB', '64MB']

r_bw_list = []
for i in range(len(object_sizes)):
    with open('./data/R'+object_sizes[i]+'.json') as f:
        data = json.load(f)
    r_bw_list.append([object_sizes[i],data['jobs'][0]['read']['bw']/1000])

r_bw_df = pd.DataFrame(r_bw_list, columns=['object size','bandwidth[MB/s]'])
display(r_bw_df)

fig = r_bw_df.plot(x='object size', y='bandwidth[MB/s]', title='Read Bandwidth' ,legend=False, xticks=r_bw_df.index , figsize=[8,5])
fig.set_ylabel("bandwidth[MB/s]")
fig.set_ylim(ymin=0)
plt.show()
# Out:
#   object size  bandwidth[MB/s]
# 0      0.25MB           83.359
# 1       0.5MB           64.244
# 2         1MB           67.846
# 3         2MB           76.690
# 4         4MB           82.498
# 5         8MB           86.690
# 6        16MB           84.745
# 7        32MB           86.938
# 8        64MB           88.169

# %% [markdown]
# <center> <h3> Sequential Write Latency vs. Object Sizes </h3> </center>

# %%
object_sizes = ['0.25MB','0.5MB', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB', '64MB']

w_lat_list = []
for i in range(len(object_sizes)):
    with open('./data/W'+object_sizes[i]+'.json') as f:
        data = json.load(f)
    w_lat_list.append([object_sizes[i],data['jobs'][0]['write']['lat_ns']['mean']/1000000])

w_lat_df = pd.DataFrame(w_lat_list, columns=['object size','latency[msec]'])
display(w_lat_df)

fig = w_lat_df.plot(x='object size', y='latency[msec]', title='Write Latency' ,legend=False, xticks=w_lat_df.index , figsize=[8,5])
fig.set_ylabel("latency[msec]")
plt.show()
# Out:
#   object size  latency[msec]
# 0      0.25MB       6.488383
# 1       0.5MB      15.977969
# 2         1MB      28.163517
# 3         2MB      53.958427
# 4         4MB     106.194054
# 5         8MB     238.311316
# 6        16MB     437.843318
# 7        32MB     916.142318
# 8        64MB    1736.997226

# %% [markdown]
# <center> <h3> Sequential Read Latency vs. Object Sizes </h3> </center>

# %%
object_sizes = ['0.25MB','0.5MB', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB', '64MB']

r_lat_list = []
for i in range(len(object_sizes)):
    with open('./data/R'+object_sizes[i]+'.json') as f:
        data = json.load(f)
    r_lat_list.append([object_sizes[i],data['jobs'][0]['read']['lat_ns']['mean']/1000000])

r_lat_df = pd.DataFrame(r_lat_list, columns=['object size','latency[msec]'])
display(r_lat_df)

fig = r_lat_df.plot(x='object size', y='latency[msec]', title='Read Latency' ,legend=False, xticks=r_lat_df.index , figsize=[8,5])
fig.set_ylabel("latency[msec]")
plt.show()
# Out:
#   object size  latency[msec]
# 0      0.25MB       3.067835
# 1       0.5MB       7.965481
# 2         1MB      15.088506
# 3         2MB      26.700362
# 4         4MB      49.644702
# 5         8MB      94.490801
# 6        16MB     193.321632
# 7        32MB     376.899818
# 8        64MB     743.282003

# %%
#read json result
object_sizes = ['0.25MB','0.5MB', '1MB', '2MB', '4MB', '8MB', '16MB', '32MB', '64MB']
for i in range(len(object_sizes)):
    with open('./data/R'+object_sizes[i]+'.json') as f:
        data = json.load(f)

    #transform data
    percentiles_df = pd.DataFrame(data['jobs'][0]['read']['clat_ns']['percentile'],index=['latency'])
    percentiles_df = percentiles_df.T
    percentiles_df = percentiles_df.reset_index()
    percentiles_df.rename(columns={'index': 'percentiles'}, inplace=True)

    #format data
    percentiles_df[['percentiles']] = percentiles_df[['percentiles']].astype(float).applymap('{:,.2f}'.format)
    percentiles_df[['latency']] = percentiles_df[['latency']].astype(int).applymap(lambda x: x/1000000)

    #display table
    #display(percentiles_df)

    #display graph
    obj_size = object_sizes[i]
    fig = percentiles_df.plot(x='percentiles', y='latency', title="Write latency percentiles (object size =" + obj_size + ')' ,legend=False, xticks=percentiles_df.index , figsize=[11,6])
    fig.set_ylabel("latency[msec/io]")
    plt.show()

# %% [markdown]
# <center> <h3> Write Bandwidth vs. Latency </h3> </center>

# %%
#numjobs = ['1','2','4','8','16','32','64']
iops = list(map(lambda x: str(x), range(1,21)))

iops_bw = []
#jobnum_lat = []
iops_lat = []


for i in range(len(iops)):
    with open('./data/W4MB_'+iops[i]+'.json') as f:
        data = json.load(f)
    # bw_lat.append([data['jobs'][0]['write']['bw']/1000,data['jobs'][0]['write']['lat_ns']['mean']/1000000])
    iops_bw.append([iops[i], data['jobs'][0]['write']['bw']/1000])
    iops_lat.append([iops[i], data['jobs'][0]['write']['lat_ns']['mean']/1000000])
    
#bw_lat = pd.DataFrame(bw_lat, columns=['bandwidth','latency'])
iops_bw = pd.DataFrame(iops_bw, columns=['bandwidth[IO/s]','bandwidth[MB/s]'])
iops_lat = pd.DataFrame(iops_lat, columns=['bandwidth[IO/s]','latency[msec]'])
# display(bw_lat)
display(iops_bw)
display(iops_lat)

# fig = bw_lat.plot(kind='line', x='bandwidth', y='latency', title='Write bandwidth vs. Latency' ,legend=False, xticks=bw_lat.bandwidth, fontsize = 8 , rot = 90, figsize=[12,5])
# fig.set_ylabel("latency[msec]")


fig_iops_w = iops_bw.plot(kind='line', x='bandwidth[IO/s]', y='bandwidth[MB/s]', title='IO/s vs. bandwidth' ,legend=False, xticks=iops_bw.index,  figsize=[8,5])
fig_iops_w.set_ylabel("bandwidth[MB/s]")
fig_iops_w.set_ylim(ymin=0)

fig_iops_lt = iops_lat.plot(kind='line', x='bandwidth[IO/s]', y='latency[msec]', title='IO/s vs. latency' ,legend=False, xticks=iops_lat.index,  figsize=[8,5])
fig_iops_lt.set_ylabel("latency[msec]")
fig_iops_lt.set_ylim(ymin=0)

plt.show()
# Out:
#    bandwidth[IO/s]  bandwidth[MB/s]
# 0                1            4.098
# 1                2            8.197
# 2                3           12.294
# 3                4           16.391
# 4                5           20.487
# 5                6           24.582
# 6                7           28.677
# 7                8           32.732
# 8                9           36.865
# 9               10           39.425
# 10              11           39.028
# 11              12           39.259
# 12              13           39.338
# 13              14           38.927
# 14              15           39.263
# 15              16           39.261
# 16              17           39.435
# 17              18           39.055
# 18              19           39.047
# 19              20           39.322
#    bandwidth[IO/s]  latency[msec]
# 0                1     196.761874
# 1                2     104.004189
# 2                3     103.476860
# 3                4     105.254498
# 4                5     104.635274
# 5                6     106.083396
# 6                7     104.278860
# 7                8     106.148839
# 8                9     105.496388
# 9               10     103.886499
# 10              11     104.944556
# 11              12     104.324211
# 12              13     104.116001
# 13              14     105.214531
# 14              15     104.313524
# 15              16     104.321507
# 16              17     103.860054
# 17              18     104.869748
# 18              19     104.893609
# 19              20     104.157332

# %% [markdown]
# <center> <h3> Read Bandwidth vs. Object Sizes </h3> </center>

# %%
#numjobs = ['1','2','4','8','16','32','64']
iops = list(map(lambda x: str(x), range(1,31)))

iops_bw = []
#jobnum_lat = []
iops_lat = []


for i in range(len(iops)):
    with open('./data/R4MB_'+iops[i]+'.json') as f:
        data = json.load(f)
    # bw_lat.append([data['jobs'][0]['write']['bw']/1000,data['jobs'][0]['write']['lat_ns']['mean']/1000000])
    iops_bw.append([iops[i], data['jobs'][0]['read']['bw']/1000])
    iops_lat.append([iops[i], data['jobs'][0]['read']['lat_ns']['mean']/1000000])
    
#bw_lat = pd.DataFrame(bw_lat, columns=['bandwidth','latency'])
iops_bw = pd.DataFrame(iops_bw, columns=['bandwidth[IO/s]','bandwidth[MB/s]'])
iops_lat = pd.DataFrame(iops_lat, columns=['bandwidth[IO/s]','latency[msec]'])
# display(bw_lat)
display(iops_bw)
display(iops_lat)

# fig = bw_lat.plot(kind='line', x='bandwidth', y='latency', title='Write bandwidth vs. Latency' ,legend=False, xticks=bw_lat.bandwidth, fontsize = 8 , rot = 90, figsize=[12,5])
# fig.set_ylabel("latency[msec]")


fig_iops_w = iops_bw.plot(kind='line', x='bandwidth[IO/s]', y='bandwidth[MB/s]', title='IO/s vs. bandwidth' ,legend=False, xticks=iops_bw.index,  figsize=[8,5])
fig_iops_w.set_ylabel("bandwidth[MB/s]")
fig_iops_w.set_ylim(ymin=0)

fig_iops_lt = iops_lat.plot(kind='line', x='bandwidth[IO/s]', y='latency[msec]', title='IO/s vs. latency' ,legend=False, xticks=iops_lat.index,  figsize=[8,5])
fig_iops_lt.set_ylabel("latency[msec]")
fig_iops_lt.set_ylim(ymin=0)

plt.show()
# Out:
#    bandwidth[IO/s]  bandwidth[MB/s]
# 0                1            4.099
# 1                2            8.197
# 2                3           12.296
# 3                4           16.394
# 4                5           20.491
# 5                6           24.583
# 6                7           28.186
# 7                8           32.572
# 8                9           35.643
# 9               10           40.973
# 10              11           45.070
# 11              12           49.167
# 12              13           49.789
# 13              14           56.318
# 14              15           61.448
# 15              16           65.544
# 16              17           69.633
# 17              18           73.736
# 18              19           77.824
# 19              20           81.916
# 20              21           42.106
# 21              22           63.801
# 22              23           71.488
# 23              24           74.057
# 24              25           82.656
# 25              26           82.619
# 26              27           82.925
# 27              28           83.018
# 28              29           82.726
# 29              30           82.423
#    bandwidth[IO/s]  latency[msec]
# 0                1      61.265350
# 1                2      53.338567
# 2                3      52.510183
# 3                4      55.654924
# 4                5      56.112307
# 5                6      62.861063
# 6                7     124.079869
# 7                8     116.468541
# 8                9     112.119770
# 9               10      95.931163
# 10              11      51.293714
# 11              12      50.336643
# 12              13      64.939795
# 13              14      52.000870
# 14              15      59.382935
# 15              16      50.477700
# 16              17      50.053141
# 17              18      49.592445
# 18              19      49.858480
# 19              20      49.754363
# 20              21      97.271128
# 21              22      64.192219
# 22              23      57.290192
# 23              24      55.302442
# 24              25      49.548381
# 25              26      49.570768
# 26              27      49.387713
# 27              28      49.332309
# 28              29      49.506673
# 29              30      49.689116

# %%
object_sizes = ['1MB', '2MB', '4MB', '8MB', '16MB', '32MB', '64MB']
w_bw_list = []
for i in range(len(object_sizes)):
    with open('./obj_interface/'+object_sizes[i]+'_W.log') as f:
        lines=f.readlines()
        for j in range(len(lines)):
            if 'Bandwidth (MB/sec):' in lines[j]:
                values = lines[j].split(':')
                w_bw_list.append([object_sizes[i],float(values[1])])

w_bw_df = pd.DataFrame(w_bw_list, columns=['object size','bandwidth[MB/s]'])
display(w_bw_df)

fig = w_bw_df.plot(x='object size', y='bandwidth[MB/s]', title='Write Bandiwidth(object interface)' ,legend=False, xticks=w_bw_df.index , figsize=[8,5])
fig.set_ylabel("bandwidth[MB/s]")
plt.show()
# Out:
#   object size  bandwidth[MB/s]
# 0         1MB          309.354
# 1         2MB          324.848
# 2         4MB          417.608
# 3         8MB          434.615
# 4        16MB          339.567
# 5        32MB          217.397
# 6        64MB          102.633

# %%
object_sizes = ['1MB', '2MB', '4MB', '8MB', '16MB', '32MB', '64MB']
w_lat_list = []
for i in range(len(object_sizes)):
    with open('./obj_interface/'+object_sizes[i]+'_W.log') as f:
        lines=f.readlines()
        for j in range(len(lines)):
            if 'Average Latency(s)' in lines[j]:
                values = lines[j].split(':')
                w_lat_list.append([object_sizes[i],float(values[1])])

w_lat_df = pd.DataFrame(w_lat_list, columns=['object size','latency[s]'])
display(w_lat_df)

fig = w_lat_df.plot(x='object size', y='latency[s]', title='Write Latency (object interface)' ,legend=False, xticks=w_lat_df.index , figsize=[8,5])
fig.set_ylabel("latency[s]")
plt.show()
# Out:
#   object size  latency[s]
# 0         1MB    0.051703
# 1         2MB    0.098473
# 2         4MB    0.152851
# 3         8MB    0.293196
# 4        16MB    0.730308
# 5        32MB    2.085410
# 6        64MB    5.814720

# %%
object_sizes = ['1MB', '2MB', '4MB', '8MB', '16MB', '32MB', '64MB']
r_bw_list = []
for i in range(len(object_sizes)):
    with open('./obj_interface/'+object_sizes[i]+'_R.log') as f:
        lines=f.readlines()
        for j in range(len(lines)):
            if 'Bandwidth (MB/sec):' in lines[j]:
                values = lines[j].split(':')
                r_bw_list.append([object_sizes[i],float(values[1])])

r_bw_df = pd.DataFrame(r_bw_list, columns=['object size','bandwidth[MB/s]'])
display(r_bw_df)

fig = r_bw_df.plot(x='object size', y='bandwidth[MB/s]', title='Read Bandiwidth(object interface)' ,legend=False, xticks=r_bw_df.index , figsize=[8,5])
fig.set_ylabel("bandwidth[MB/s]")
plt.show()
# Out:
#   object size  bandwidth[MB/s]
# 0         1MB         667.1990
# 1         2MB         946.9970
# 2         4MB        1081.1100
# 3         8MB         764.6080
# 4        16MB         446.4980
# 5        32MB         260.2790
# 6        64MB          96.7602

# %%
object_sizes = ['1MB', '2MB', '4MB', '8MB', '16MB', '32MB', '64MB']
r_lat_list = []
for i in range(len(object_sizes)):
    with open('./obj_interface/'+object_sizes[i]+'_R.log') as f:
        lines=f.readlines()
        for j in range(len(lines)):
            if 'Average Latency(s)' in lines[j]:
                values = lines[j].split(':')
                r_lat_list.append([object_sizes[i],float(values[1])])

r_lat_df = pd.DataFrame(r_lat_list, columns=['object size','latency[s]'])
display(r_lat_df)

fig = r_lat_df.plot(x='object size', y='latency[s]', title='Read Latency (object interface)' ,legend=False, xticks=r_lat_df.index , figsize=[8,5])
fig.set_ylabel("latency[s]")
plt.show()
# Out:
#   object size  latency[s]
# 0         1MB    0.023678
# 1         2MB    0.033214
# 2         4MB    0.057868
# 3         8MB    0.163742
# 4        16MB    0.549008
# 5        32MB    1.704790
# 6        64MB    5.951940
